# %%
import os
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

import nibabel as nib

# %%
data = nib.load('./dataset/mouse_brain/MBrain_57008_0000.nii.gz')
data.get_fdata().shape
# Out:
# (256, 420, 256)

# %%
plt.imshow(data.get_fdata()[:,:,128])

# %%
def ShowSlicesAcrossAxis(data, axis, numberOfSlices, steps):
    if axis == 'x':
        plt.figure(figsize=(20, 20))
        for i in range(1,11):
            plt.subplot(1,10,i)
            plt.imshow(data.get_fdata()[i*5,:,:], 'gray', interpolation='none')
        plt.show()
ShowSlicesAcrossAxis(data, 'x', 5, 1)
